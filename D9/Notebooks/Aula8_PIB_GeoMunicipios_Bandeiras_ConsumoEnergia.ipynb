# %% [markdown]
# # ETL para carregar as bandeiras dos estados, PIB Percapita, Centróide dos municípios e Consumo de Energia

# %%
import pandas as pd
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
project_id = 'enap-331414'
# Out:
# Authenticated

# %% [markdown]
# ## 1) Centroides dos municipios

# %% [markdown]
# ### 1.1) Download do arquivo de Localidades e limpeza/tratamento dos dados.
# #### URL do arquivo exportado para xlsx https://github.com/alexlopespereira/enapespcd2021/raw/main/data/originais/centroide_municipios/BR_Localidades_2010_v1.xlsx

# %%
df_xlsx = pd.read_excel('https://github.com/alexlopespereira/enapespcd2021/raw/main/data/originais/centroide_municipios/BR_Localidades_2010_v1.xlsx', dtype={"CD_GEOCODM,C,20":str})
dfxlsx_geo = df_xlsx[['CD_GEOCODM,C,20','NM_CATEGOR,C,50','LONG,N,24,6','LAT,N,24,6']].rename(columns={'CD_GEOCODM,C,20':"cod_ibge", 'NM_CATEGOR,C,50':"categoria", 'LONG,N,24,6':"long", 'LAT,N,24,6':"lat"})
dfxlsx_geo['categoria'] = dfxlsx_geo['categoria'].str.strip()
dfxlsx_geo = dfxlsx_geo[dfxlsx_geo['categoria']=='CIDADE']
dfxlsx_geo['lat_long'] = dfxlsx_geo[['lat','long']].apply(lambda x: f"{str(x['lat']).replace(',','.')},{str(x['long']).replace(',','.')}", axis=1)
dfxlsx_geo.head()
# Out:
#    cod_ibge categoria  ...        lat                             lat_long
# 0   1100015    CIDADE  ... -11.935540  -11.9355403047646,-61.9998238962936
# 6   1100023    CIDADE  ...  -9.908463   -9.9084628665672,-63.0332692780484
# 7   1100031    CIDADE  ... -13.499763  -13.4997634596963,-60.5443135812009
# 9   1100049    CIDADE  ... -11.433865  -11.4338650286852,-61.4429442118224
# 18  1100056    CIDADE  ... -13.195033  -13.1950330320399,-60.8184261646815
#
# [5 rows x 5 columns]

# %% [markdown]
# ## 2) Join com a tabela de PIB per capita

# %% [markdown]
# ### 2.1) Criar dataframe do PIB e População

# %%
## Defina o id do seu projeto no bigquery!!!!!
project_id = 'enap-331414' # Defina o id do seu projeto no bigquery!!!!!
## Defina o id do seu projeto no bigquery!!!!!

df_pibpercapita = pd.io.gbq.read_gbq('''
SELECT pop.*, dsc.nome_municipio, pib.pib, pib.pib/pop.populacao as pibpercapita FROM `basedosdados.br_ibge_populacao.municipio` pop
LEFT JOIN `basedosdados.br_ibge_pib.municipio` pib on pop.id_municipio = pib.id_municipio and pib.ano = pop.ano
LEFT JOIN (
 select distinct (sc.id_municipio), sc.nome_municipio from `basedosdados.br_geobr_mapas.setor_censitario_2010` sc
 ) as dsc on dsc.id_municipio = pop.id_municipio
''', project_id=project_id)

df_pibpercapita.head()
# Out:
#     ano sigla_uf id_municipio  ...         nome_municipio pib  pibpercapita
# 0  1991       RO      1100015  ...  Alta Floresta D'oeste NaN           NaN
# 1  1992       RO      1100015  ...  Alta Floresta D'oeste NaN           NaN
# 2  1993       RO      1100015  ...  Alta Floresta D'oeste NaN           NaN
# 3  1994       RO      1100015  ...  Alta Floresta D'oeste NaN           NaN
# 4  1995       RO      1100015  ...  Alta Floresta D'oeste NaN           NaN
#
# [5 rows x 7 columns]

# %% [markdown]
# ### 2.1) Merge do dataframe do centroid com o dataframe do pib percapita

# %%
df_merge = df_pibpercapita.merge(dfxlsx_geo[['cod_ibge','lat_long']], how='left', left_on='id_municipio', right_on='cod_ibge') 
del df_merge['cod_ibge']
df_merge.head()
# Out:
#     ano sigla_uf  ... pibpercapita                             lat_long
# 0  1991       RO  ...          NaN  -11.9355403047646,-61.9998238962936
# 1  1992       RO  ...          NaN  -11.9355403047646,-61.9998238962936
# 2  1993       RO  ...          NaN  -11.9355403047646,-61.9998238962936
# 3  1994       RO  ...          NaN  -11.9355403047646,-61.9998238962936
# 4  1995       RO  ...          NaN  -11.9355403047646,-61.9998238962936
#
# [5 rows x 8 columns]

# %% [markdown]
# ## 3) Criar o dataframe das bandeiras

# %%
dfb = pd.read_excel("https://github.com/alexlopespereira/enapespcd2021/raw/main/data/originais/bandeiras/bandeiras.xlsx")
dfb.head()
# Out:
#      ufNome  uf                                           Bandeira
# 0      Acre  AC  https://upload.wikimedia.org/wikipedia/commons...
# 1   Alagoas  AL  https://upload.wikimedia.org/wikipedia/commons...
# 2     Amapá  AP  https://upload.wikimedia.org/wikipedia/commons...
# 3  Amazonas  AM  https://upload.wikimedia.org/wikipedia/commons...
# 4     Bahia  BA  https://upload.wikimedia.org/wikipedia/commons...

# %%
dfb['Bandeira'][0]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Bandeira_do_Acre.svg/320px-Bandeira_do_Acre.svg.png'

# %% [markdown]
# ### 3) Fazer o merge com a tabela do pib percapita

# %%
df_merge = df_merge.merge(dfb, left_on='sigla_uf', right_on='uf')

# %% [markdown]
# ### 4) Criar o dataframe de consumo de energia
# #### Filtrar pelo tipo de consumo igual a Total

# %%
df_energia = pd.io.gbq.read_gbq('''
 SELECT ano, sigla_uf, sum(consumo) as consumo_anual_uf 
 FROM `basedosdados.br_mme_consumo_energia_eletrica.uf` 
 WHERE tipo_consumo='Total'
 GROUP BY ano, sigla_uf
 ''', project_id=project_id)

df_energia.head()
# Out:
#     ano sigla_uf  consumo_anual_uf
# 0  2004       RO        1344908.30
# 1  2004       AC         415795.58
# 2  2004       AM        3525109.61
# 3  2004       RR         369887.41
# 4  2004       PA       12748429.17

# %% [markdown]
# ### 5) Join com a tabela fato (PIB, População, Geo, Bandeiras)
# #### **Solução**: Adicionar ao modelo o Consumo de Energia somente no 1o registro de cada subgrupo UF/Municipio
# #### **Pergunta**: Como identificar o 1o registro de cada subgrupo?
# ##### **Resposta:** Com a função cumcount (Cumulative Count) do pandas

# %% [markdown]
# #### Exemplo da função cumcount com GROUP BY ?
# ##### Considere o seguinte dataframe fictício com a população dos municípios

# %%
df_pop_exemplo = pd.DataFrame([ [2020, 'SP', 10, 'A'], [2020, 'SP', 20, 'B'], [2020, 'SP', 30, 'C'], [2020, 'CE', 5, 'D'], [2020, 'CE', 6, 'E'],  [2020, 'CE', 7, 'F'],  [2020, 'MG', 10, 'H'],
 [2020, 'MG', 11, 'I'], [2020, 'MG', 12, 'J'],   [2021, 'SP', 10, 'A'], [2021, 'SP', 20, 'B'], [2021, 'SP', 30, 'C'], [2021, 'CE', 5, 'D'],
 [2021, 'CE', 6, 'E'],  [2021, 'CE', 7, 'F'],  [2021, 'MG', 10, 'H'], [2021, 'MG', 11, 'I'], [2021, 'MG', 12, 'J'] ], columns = ['Ano', 'UF', 'pop_municipio', 'Municipio'])
df_pop_exemplo.head(12)
# Out:
#      Ano  UF  pop_municipio Municipio
# 0   2020  SP             10         A
# 1   2020  SP             20         B
# 2   2020  SP             30         C
# 3   2020  CE              5         D
# 4   2020  CE              6         E
# 5   2020  CE              7         F
# 6   2020  MG             10         H
# 7   2020  MG             11         I
# 8   2020  MG             12         J
# 9   2021  SP             10         A
# 10  2021  SP             20         B
# 11  2021  SP             30         C

# %%
df_pop_exemplo.groupby(['Ano', 'UF']).cumcount().rename('rank')
# Out:
# 0     0
# 1     1
# 2     2
# 3     0
# 4     1
# 5     2
# 6     0
# 7     1
# 8     2
# 9     0
# 10    1
# 11    2
# 12    0
# 13    1
# 14    2
# 15    0
# 16    1
# 17    2
# Name: rank, dtype: int64

# %%
# Criando uma coluna para guardar o ranking (posição dentro do subgrupo)
df_pop_exemplo['rank'] = df_pop_exemplo.groupby(['Ano', 'UF']).cumcount()
df_pop_exemplo
# Out:
#      Ano  UF  pop_municipio Municipio  rank
# 0   2020  SP             10         A     0
# 1   2020  SP             20         B     1
# 2   2020  SP             30         C     2
# 3   2020  CE              5         D     0
# 4   2020  CE              6         E     1
# 5   2020  CE              7         F     2
# 6   2020  MG             10         H     0
# 7   2020  MG             11         I     1
# 8   2020  MG             12         J     2
# 9   2021  SP             10         A     0
# 10  2021  SP             20         B     1
# 11  2021  SP             30         C     2
# 12  2021  CE              5         D     0
# 13  2021  CE              6         E     1
# 14  2021  CE              7         F     2
# 15  2021  MG             10         H     0
# 16  2021  MG             11         I     1
# 17  2021  MG             12         J     2

# %% [markdown]
# #### Considere o dataframe fictício de consumo de energia

# %%
df_energia_exemplo = pd.DataFrame([[2020, 'SP', 1000], [2020, 'CE', 50], [2020, 'MG', 100], [2021, 'SP', 1200], [2021, 'CE', 60], [2021, 'MG', 211]], columns = ['Ano', 'UF', 'Consumo'])
df_energia_exemplo
# Out:
#     Ano  UF  Consumo
# 0  2020  SP     1000
# 1  2020  CE       50
# 2  2020  MG      100
# 3  2021  SP     1200
# 4  2021  CE       60
# 5  2021  MG      211

# %%
df_energia_exemplo['rank'] = 0
df_energia_exemplo
# Out:
#     Ano  UF  Consumo  rank
# 0  2020  SP     1000     0
# 1  2020  CE       50     0
# 2  2020  MG      100     0
# 3  2021  SP     1200     0
# 4  2021  CE       60     0
# 5  2021  MG      211     0

# %%
# Fazer o merge dos dataframes  considerando o ranking como parte da chave
dfm_exemplo = df_pop_exemplo.merge(df_energia_exemplo, on=['Ano','UF','rank'], how='left')
dfm_exemplo.head(12)
# Out:
#      Ano  UF  pop_municipio Municipio  rank  Consumo
# 0   2020  SP             10         A     0   1000.0
# 1   2020  SP             20         B     1      NaN
# 2   2020  SP             30         C     2      NaN
# 3   2020  CE              5         D     0     50.0
# 4   2020  CE              6         E     1      NaN
# 5   2020  CE              7         F     2      NaN
# 6   2020  MG             10         H     0    100.0
# 7   2020  MG             11         I     1      NaN
# 8   2020  MG             12         J     2      NaN
# 9   2021  SP             10         A     0   1200.0
# 10  2021  SP             20         B     1      NaN
# 11  2021  SP             30         C     2      NaN

# %% [markdown]
# ### Aplicando essas operações ao dado real de consumo de energia

# %%
df_merge2 = df_merge.copy()

# %%
df_merge2['rank'] = df_merge2.groupby(['ano', 'sigla_uf']).cumcount()
df_merge2.head(40)
# Out:
#      ano sigla_uf  ...                                           Bandeira  rank
# 0   1991       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 1   1992       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 2   1993       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 3   1994       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 4   1995       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 5   1996       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 6   1997       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 7   1998       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 8   1999       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 9   2000       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 10  2001       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 11  2002       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 12  2003       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 13  2004       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 14  2005       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 15  2006       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 16  2007       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 17  2008       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 18  2009       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 19  2010       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 20  2011       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 21  2012       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 22  2013       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 23  2014       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 24  2015       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 25  2016       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 26  2017       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 27  2018       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 28  2019       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 29  2020       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 30  2021       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     0
# 31  1991       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 32  1992       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 33  1993       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 34  1994       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 35  1995       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 36  1996       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 37  1997       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 38  1998       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
# 39  1999       RO  ...  https://upload.wikimedia.org/wikipedia/commons...     1
#
# [40 rows x 12 columns]

# %%
df_energia2 = df_energia.copy()
df_energia2['rank'] = 0
df_energia2.head()
# Out:
#     ano sigla_uf  consumo_anual_uf  rank
# 0  2004       RO        1344908.30     0
# 1  2004       AC         415795.58     0
# 2  2004       AM        3525109.61     0
# 3  2004       RR         369887.41     0
# 4  2004       PA       12748429.17     0

# %%
df_merge2 = df_merge2.merge(df_energia2, on=['ano','sigla_uf','rank'], how='left')
df_merge2.head(40)
# Out:
#      ano sigla_uf  ... rank  consumo_anual_uf
# 0   1991       RO  ...    0               NaN
# 1   1992       RO  ...    0               NaN
# 2   1993       RO  ...    0               NaN
# 3   1994       RO  ...    0               NaN
# 4   1995       RO  ...    0               NaN
# 5   1996       RO  ...    0               NaN
# 6   1997       RO  ...    0               NaN
# 7   1998       RO  ...    0               NaN
# 8   1999       RO  ...    0               NaN
# 9   2000       RO  ...    0               NaN
# 10  2001       RO  ...    0               NaN
# 11  2002       RO  ...    0               NaN
# 12  2003       RO  ...    0               NaN
# 13  2004       RO  ...    0        1344908.30
# 14  2005       RO  ...    0        1439326.00
# 15  2006       RO  ...    0        1523904.00
# 16  2007       RO  ...    0        1633805.00
# 17  2008       RO  ...    0        1749852.00
# 18  2009       RO  ...    0        1913755.00
# 19  2010       RO  ...    0        2184581.00
# 20  2011       RO  ...    0        2377847.00
# 21  2012       RO  ...    0        2826148.00
# 22  2013       RO  ...    0        2930424.00
# 23  2014       RO  ...    0        3031531.00
# 24  2015       RO  ...    0        3033049.00
# 25  2016       RO  ...    0        2944371.00
# 26  2017       RO  ...    0        3066940.00
# 27  2018       RO  ...    0        3153177.08
# 28  2019       RO  ...    0        3247614.58
# 29  2020       RO  ...    0        3387627.03
# 30  2021       RO  ...    0        1584155.42
# 31  1991       RO  ...    1               NaN
# 32  1992       RO  ...    1               NaN
# 33  1993       RO  ...    1               NaN
# 34  1994       RO  ...    1               NaN
# 35  1995       RO  ...    1               NaN
# 36  1996       RO  ...    1               NaN
# 37  1997       RO  ...    1               NaN
# 38  1998       RO  ...    1               NaN
# 39  1999       RO  ...    1               NaN
#
# [40 rows x 13 columns]

# %% [markdown]
# ### Criando uma função para realizar esta operação de merge

# %%
def merge_chave_menor(df_mais_granular, df_menos_granular, chaves_comuns):
  df_mais_granular['rank'] = df_mais_granular.groupby(chaves_comuns).cumcount()
  df_menos_granular['rank'] = 0
  chaves_com_rank = chaves_comuns.append('rank')
  dfr = df_mais_granular.merge(df_menos_granular, on=chaves_com_rank, how='left')
  del dfr['rank']
  return dfr

# %%
dfm = merge_chave_menor(df_merge, df_energia, ['ano','sigla_uf'])
dfm.head(40)
# Out:
#      ano  ... consumo_anual_uf
# 0   1991  ...              NaN
# 1   1992  ...              NaN
# 2   1993  ...              NaN
# 3   1994  ...              NaN
# 4   1995  ...              NaN
# 5   1996  ...              NaN
# 6   1997  ...              NaN
# 7   1998  ...              NaN
# 8   1999  ...              NaN
# 9   2000  ...              NaN
# 10  2001  ...              NaN
# 11  2002  ...              NaN
# 12  2003  ...              NaN
# 13  2004  ...       1344908.30
# 14  2005  ...       1439326.00
# 15  2006  ...       1523904.00
# 16  2007  ...       1633805.00
# 17  2008  ...       1749852.00
# 18  2009  ...       1913755.00
# 19  2010  ...       2184581.00
# 20  2011  ...       2377847.00
# 21  2012  ...       2826148.00
# 22  2013  ...       2930424.00
# 23  2014  ...       3031531.00
# 24  2015  ...       3033049.00
# 25  2016  ...       2944371.00
# 26  2017  ...       3066940.00
# 27  2018  ...       3153177.08
# 28  2019  ...       3247614.58
# 29  2020  ...       3387627.03
# 30  2021  ...       1584155.42
# 31  1991  ...              NaN
# 32  1992  ...              NaN
# 33  1993  ...              NaN
# 34  1994  ...              NaN
# 35  1995  ...              NaN
# 36  1996  ...              NaN
# 37  1997  ...              NaN
# 38  1998  ...              NaN
# 39  1999  ...              NaN
#
# [40 rows x 12 columns]

# %% [markdown]
# ### 6) Enviar o dataframe de resultado ao BigQuery.
# #### Decida se lhe é conveniente reutilizar a tabela e o data source no Data Studio, ou se deseja criar uma nova tabela e um novo data source.
# #### Dica 1: Se esta operação apenas adicionar colunas à tabela, sem remover outras, pode reutilizar a tabela e o data source.
# #### Dica 2: Se reutilizar a tabela, atualize os campos do seu data source.

# %%
dfm.to_gbq("enapdatasets.pibpercapita",
  project_id=project_id,
  chunksize=40000,
  if_exists='replace',
  )
# Out:
# 5it [00:36,  7.25s/it]

# %% [markdown]
# ### Ajustando dados para o vega-lite

# %% [markdown]
# #### Dados com ID dos munipios

# %%
dfm.loc[ dfm['consumo_anual_uf'].notnull() ,['ano','sigla_uf','id_municipio','consumo_anual_uf']].to_csv("./consumo_energia.csv")

# %% [markdown]
# #### Dados sem ID dos municipios e somente o ano de 2021

# %%
map_uf={'AC': '12',
  'AL': '27',
  'AM': '13',
  'AP': '16',
  'BA': '29',
  'CE': '23',
  'DF': '53',
  'ES': '32',
  'GO': '52',
  'MA': '21',
  'MG': '31',
  'MS': '50',
  'MT': '51',
  'PA': '15',
  'PB': '25',
  'PE': '26',
  'PI': '22',
  'PR': '41',
  'RJ': '33',
  'RN': '24',
  'RO': '11',
  'RR': '14',
  'RS': '43',
  'SC': '42',
  'SE': '28',
  'SP': '35',
  'TO': '17'}

# %%
df_energia['codarea'] = df_energia['sigla_uf'].map(map_uf)
df_energia_2021 = df_energia[df_energia['ano']==2021]
df_energia_2021.loc[:,'consumo_anual_uf']=df_energia_2021.loc[:, 'consumo_anual_uf'].astype(int)
df_energia_2021['rate'] = df_energia_2021['consumo_anual_uf']/df_energia_2021['consumo_anual_uf'].max()
df_energia_2021['rate'] = df_energia_2021['rate'].round(3)

df_energia_2021.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       ano sigla_uf  consumo_anual_uf codarea   rate
# 459  2021       RO           1584155      11  0.023
# 460  2021       AC            525328      12  0.008
# 461  2021       AM           2917092      13  0.042
# 462  2021       RR            502832      14  0.007
# 463  2021       PA          10345601      15  0.150

# %%
df_energia_2021.to_csv('./consumo_2021_uf.csv', index=False)

# %%
df_energia_2021[['codarea','rate']].to_json('./consumo_2021_uf.json', orient='records')

# %%
# !pip install pandera
# Out:
# Collecting pandera
#   Downloading pandera-0.8.0-py3-none-any.whl (186 kB)
#      |████████████████████████████████| 186 kB 25.3 MB/s
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.1.5)
# Collecting pandas-stubs
#   Downloading pandas_stubs-1.2.0.39-py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 37.8 MB/s
# Collecting typing-inspect>=0.6.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandera) (3.10.0.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from pandera) (1.13.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (21.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from pandera) (3.0.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pandera) (1.19.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->pandera) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->pandera) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->pandera) (1.15.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pandas-stubs, pandera
# Successfully installed mypy-extensions-0.4.3 pandas-stubs-1.2.0.39 pandera-0.8.0 typing-inspect-0.7.1

# %%
dfm.columns.values
# Out:
# array(['ano', 'sigla_uf', 'id_municipio', 'populacao', 'nome_municipio',
#        'pib', 'pibpercapita', 'lat_long', 'ufNome', 'uf', 'Bandeira',
#        'consumo_anual_uf'], dtype=object)

# %%
import pandera as pa
import pandas as pd
import re
ufs = ['RO', 'AC', 'AM', 'RR', 'PA', 'AP', 'TO', 'MA', 'PI', 'CE', 'RN',
       'PB', 'PE', 'AL', 'SE', 'BA', 'MG', 'ES', 'RJ', 'SP', 'PR', 'SC',
       'RS', 'MS', 'MT', 'GO', 'DF']

# %%
schema = pa.DataFrameSchema(
    columns={
        'ano': pa.Column(int), 
        'sigla_uf': pa.Column(str, checks=[pa.Check.isin(ufs)]), 
        'id_municipio': pa.Column(str, nullable=True), 
        'populacao': pa.Column(float, nullable=True), 'nome_municipio': pa.Column(str, nullable=True),
       'pib': pa.Column(float, nullable=True), 
       'pibpercapita': pa.Column(float, nullable=True), 
       'lat_long': pa.Column(str, nullable=True, checks=[pa.Check.str_matches("-?\d*\.\d+\,-?\d*\.\d+")]), 
       'ufNome': pa.Column(), 'uf': pa.Column(str), 'Bandeira': pa.Column(str, nullable=True),
       'consumo_anual_uf': pa.Column(float, nullable=True)
        },
        unique=['id_municipio', 'ano']
)

# %%
# re.match("-?\d*\.\d+\,-?\d*\.\d+", "aaaaa-61.9998238962936") #
dfm['sigla_uf'].unique()
# Out:
# array(['RO', 'AC', 'AM', 'RR', 'PA', 'AP', 'TO', 'MA', 'PI', 'CE', 'RN',
#        'PB', 'PE', 'AL', 'SE', 'BA', 'MG', 'ES', 'RJ', 'SP', 'PR', 'SC',
#        'RS', 'MS', 'MT', 'GO', 'DF'], dtype=object)

# %%
schema.validate(dfm)
# Out:
#          ano  ... consumo_anual_uf
# 0       1991  ...              NaN
# 1       1992  ...              NaN
# 2       1993  ...              NaN
# 3       1994  ...              NaN
# 4       1995  ...              NaN
# ...      ...  ...              ...
# 168813  2017  ...       6210197.00
# 168814  2018  ...       6219665.08
# 168815  2019  ...       6315381.00
# 168816  2020  ...       6169523.00
# 168817  2021  ...       3144959.79
#
# [168818 rows x 12 columns]

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168818 entries, 0 to 168817
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ano               168818 non-null  int64
#  1   sigla_uf          168818 non-null  object
#  2   id_municipio      168818 non-null  object
#  3   populacao         168284 non-null  float64
#  4   nome_municipio    168768 non-null  object
#  5   pib               94616 non-null   float64
#  6   pibpercapita      94615 non-null   float64
#  7   lat_long          168768 non-null  object
#  8   ufNome            168818 non-null  object
#  9   uf                168818 non-null  object
#  10  Bandeira          168818 non-null  object
#  11  consumo_anual_uf  486 non-null     float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 16.7+ MB
