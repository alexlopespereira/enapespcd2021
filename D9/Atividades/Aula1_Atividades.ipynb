# %% [markdown]
# # Aula 1 - Atividade Complementar

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Atividade 1.1
# ### Considere o seguinte dataset

# %%
url='https://docs.google.com/spreadsheets/d/16B0uAFH1hubqvXytaxEkh9J8fXAJugYi/edit?usp=sharing'
url2='https://drive.google.com/uc?id=' + url.split('/')[-2]
df_orders = pd.read_excel(url2, sheet_name='Orders')
df_orders.head()
# Out:
#    ProductID                    ProductName  ...  CategoryID    CategoryName
# 0         11                 Queso Cabrales  ...           4  Dairy Products
# 1         42  Singaporean Hokkien Fried Mee  ...           5  Grains/Cereals
# 2         72         Mozzarella di Giovanni  ...           4  Dairy Products
# 3         14                           Tofu  ...           7         Produce
# 4         51          Manjimup Dried Apples  ...           7         Produce
#
# [5 rows x 14 columns]

# %% [markdown]
# #### Trace um gráfico temporal (de linha) com o faturamento/venda ($) total de cada categoria desta tabela. Pense em qual a escala temporal mais apropriada para analisar os dados. Diario? Semanal? Mensal?
# #### Não se preocupe aqui no seaborn, quando estiver fazendo EDA, com o uso (des)apropriado de cores e de atributos pré-atenção.
